# %%
import sys
sys.path.append('/workspaces/EstructuraDatos_2026_01')

# %%
from Goodrich.ch03.prefix_averages import *

# %%
prefix_average1([1,2,3,4])
# Out:
# [1.0, 1.5, 2.0, 2.5]

# %% [markdown]
# ## **Fecha: 18/02/2026**

# %%
from Goodrich.ch05.dynamic_array import *

# %%
L = DynamicArray()

# %%
L

# %%
for i in range(1,6):
    L.append(i)

# %%
len(L), L[2]
# Out:
# (5, 3)

# %%
L._capacity, len(L)
# Out:
# (8, 5)

# %%
L.append('a'), L._capacity, len(L)
# Out:
# (None, 16, 9)

# %%
L[0], L[7], L[2]
# Out:
# (1, 'a', 3)

# %%
class DynamicArray1(DynamicArray):
    def __str__(self):
        return 'hola'

# %%
L1 = DynamicArray1()

# %%
print(L1)
# Out:
# hola
